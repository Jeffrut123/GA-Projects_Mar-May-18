# %% [markdown]
# # GA Data Science Final Project
# # Jeff Rutledge   May 8, 2018

# %% [markdown]
# Data Dictionary - The data we use in our final project consists of two separate datasets, appended together.  The datasets include 1) "Sustainalytics" Environmental, Social & Governance (ESG) scoring system and 2) U.S. S&P 1500 stock price performance.  We describe these two components individually below.

# %% [markdown]
# Sustainalytics ESG Scoring System.  Sustainalytics is a independent organization and application that my firm, Bessemer Trust, subscribes to.  Sustainalytics "scores" publicly traded companies reagrding their strategies and compliance with environmental, social, and governance (ESG) best-practices.  Sustainalytics scores each company with an overall ESG rating, individual "E", "S", and "G" scores, and ratings for several individual components with each "E", "S", and "G" category.  Each company and its respective ESG scores represent a single observation , while the ESG scores represent the model's features, or independent variables.

# %% [markdown]
# Stock Price Performance.  Our firm's equity portfolio teams utilize the FactSet Research Systems desktop application for all portfolio and risk management as well as company and industry analysis.  (This system is considered competitive with the Bloomberg Financial system.)  FactSet can interact with Microsoft Office applications, and we frequently download into spreadsheets myriad financial information ranging from stock price statistics through comprehensive individual-company SEC-reported financial statement information.  The specific dataset we will use here includes company names and stock tickers for all S&P 1500 companies and their respective stock price return information.  We also include "relative stock price returns" for each company.  (A stock's relative return refers to its performance versus the S&P 500.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
esg = pd.read_csv('ESG_Sustainalytics_US_Primary 2015.csv')

# %%
df_esg = pd.DataFrame(esg)

# %%
df_esg.head()
# Out:
#     SYMBOL      DATE     SPX YE15     SPX YE17  SPX 15-17   SEDOL  \
# 0  2108601  20151231   \t2,063.4    \t2,673.6         0.3  210860
# 1  2089427  20151231   \t2,063.4    \t2,673.6         0.3  208942
# 2  2767228  20151231   \t2,063.4    \t2,673.6         0.3  276722
# 3  2365161  20151231   \t2,063.4    \t2,673.6         0.3  236516
# 4  2020459  20151231   \t2,063.4    \t2,673.6         0.3  202045
#
#   TICKER-REGION  PRICE YE15  PRICE YE17 RETURN 15-17        ...          \
# 0         BA-US   \t146.41    \t294.91       \t1.01         ...
# 1       BEAV-US    \t42.92          NaN     \t(1.00)        ...
# 2        COL-US    \t93.27    \t135.62       \t0.45         ...
# 3         GD-US   \t139.26    \t203.45       \t0.46         ...
# 4        HON-US   \t103.87    \t153.36       \t0.48         ...
#
#       E_PRODSERVICE_INCIDENTS        S_EMPLOYEE_INCIDENTS  \
# 0  No Evidence of Controversy                  Category 3
# 1  No Evidence of Controversy  No Evidence of Controversy
# 2  No Evidence of Controversy  No Evidence of Controversy
# 3  No Evidence of Controversy                  Category 1
# 4  No Evidence of Controversy                  Category 2
#
#       S_SUPPLYCHAIN_INCIDENTS        S_CUSTOMER_INCIDENTS  \
# 0  No Evidence of Controversy                  Category 3
# 1  No Evidence of Controversy                  Category 1
# 2  No Evidence of Controversy  No Evidence of Controversy
# 3  No Evidence of Controversy  No Evidence of Controversy
# 4  No Evidence of Controversy                  Category 3
#
#         S_COMMUNITY_INCIDENTS       G_BUSETHICS_INCIDENTS  \
# 0                  Category 3                  Category 2
# 1                  Category 1                  Category 1
# 2  No Evidence of Controversy  No Evidence of Controversy
# 3                  Category 1  No Evidence of Controversy
# 4                  Category 1                  Category 1
#
#        G_GOVERNANCE_INCIDENTS   G_PUBLIC_POLICY_INCIDENTS    OLD_SYMBOL  \
# 0                  Category 2  No Evidence of Controversy  US0970231058
# 1  No Evidence of Controversy  No Evidence of Controversy  US0733021010
# 2  No Evidence of Controversy  No Evidence of Controversy  US7743411016
# 3  No Evidence of Controversy  No Evidence of Controversy  US3695501086
# 4  No Evidence of Controversy  No Evidence of Controversy  US4385161066
#
#    CONTROVERSY_LEVEL
# 0                @NA
# 1                @NA
# 2                @NA
# 3                @NA
# 4                @NA
#
# [5 rows x 43 columns]

# %%
df_esg_sum = df_esg.drop(columns=['SYMBOL', 'SEDOL', 'TICKER-REGION', 'SECURITY NAME', 'EXCHANGE', 'REGION', 'COMP_GROUP_AVG', 
                                  'E_OPERATIONS_INCIDENTS', 'E_SUPPLYCHAIN_INCIDENTS', 'E_PRODSERVICE_INCIDENTS', 'S_EMPLOYEE_INCIDENTS', 
                                  'S_SUPPLYCHAIN_INCIDENTS', 'S_CUSTOMER_INCIDENTS', 'S_COMMUNITY_INCIDENTS', 'G_BUSETHICS_INCIDENTS', 
                                  'G_GOVERNANCE_INCIDENTS', 'G_PUBLIC_POLICY_INCIDENTS', 'OLD_SYMBOL', 'CONTROVERSY_LEVEL'])

# %%
df_esg_sum = df_esg_sum.rename(columns = {'SPX YE15':'SPX15', 'SPX YE17':'SPX17', 'SPX 15-17':'SPX1517', 'PRICE YE15':'P15', 
                                          'PRICE YE17':'P17', 'RETURN 15-17':'RTN1517', 'REL-RETURN':'REL_RTN', 
                                          'ENVIRONMENT_SCORE':'E_SCORE', 'SOCIAL_SCORE':'S_SCORE', 'GOVERNANCE_SCORE':'G_SCORE', 
                                          'TOTAL_ESG_PTILE':'ESG_PTILE', 'ENVIRONMENT_PTILE':'E_PTILE', 'SOCIAL_PTILE':'S_PTILE', 
                                          'GOVERNANCE_PTILE':'G_PTILE', 'ENVIRONMENT_WEIGHT':'E_WT', 'SOCIAL_WEIGHT':'S_WT', 'GOVERNANCE_WEIGHT':'G_WT'})

# %%
df_esg_sum.head()
# Out:
#        DATE        SPX15        SPX17  SPX1517         P15         P17  \
# 0  20151231   \t2,063.4    \t2,673.6       0.3   \t146.41    \t294.91
# 1  20151231   \t2,063.4    \t2,673.6       0.3    \t42.92          NaN
# 2  20151231   \t2,063.4    \t2,673.6       0.3    \t93.27    \t135.62
# 3  20151231   \t2,063.4    \t2,673.6       0.3   \t139.26    \t203.45
# 4  20151231   \t2,063.4    \t2,673.6       0.3   \t103.87    \t153.36
#
#      RTN1517    REL_RTN        ROE                          NAME  ...   \
# 0    \t1.01     \t0.72    \t46.22             The Boeing Company  ...
# 1   \t(1.00)   \t(1.30)    \t4.41              BE Aerospace Inc.  ...
# 2    \t0.45     \t0.16    \t36.92          Rockwell Collins Inc.  ...
# 3    \t0.46     \t0.17    \t20.30   General Dynamics Corporation  ...
# 4    \t0.48     \t0.18    \t24.14   Honeywell International Inc.  ...
#
#   E_SCORE S_SCORE G_SCORE  ESG_PTILE  E_PTILE  S_PTILE  G_PTILE  E_WT  S_WT  \
# 0    62.0    45.0    59.0      25.64    56.41    12.82    10.26  0.35  0.35
# 1    40.0    44.0    59.0       2.56     0.00     7.69    10.26  0.35  0.35
# 2    70.0    66.0    75.0      76.92    82.05    79.49    82.05  0.35  0.35
# 3    54.0    51.0    60.0      25.64    30.77    25.64    15.38  0.35  0.35
# 4    50.0    54.0    74.0      38.46    20.51    35.90    79.49  0.35  0.35
#
#    G_WT
# 0   0.3
# 1   0.3
# 2   0.3
# 3   0.3
# 4   0.3
#
# [5 rows x 24 columns]

# %%
df_esg_sum1 = df_esg_sum.replace("\t"," ", regex=True)

# %%
df_esg_sum1.head()
# Out:
#        DATE       SPX15       SPX17  SPX1517        P15        P17   RTN1517  \
# 0  20151231    2,063.4     2,673.6       0.3    146.41     294.91      1.01
# 1  20151231    2,063.4     2,673.6       0.3     42.92         NaN    (1.00)
# 2  20151231    2,063.4     2,673.6       0.3     93.27     135.62      0.45
# 3  20151231    2,063.4     2,673.6       0.3    139.26     203.45      0.46
# 4  20151231    2,063.4     2,673.6       0.3    103.87     153.36      0.48
#
#     REL_RTN       ROE                          NAME  ...  E_SCORE S_SCORE  \
# 0     0.72     46.22             The Boeing Company  ...     62.0    45.0
# 1    (1.30)     4.41              BE Aerospace Inc.  ...     40.0    44.0
# 2     0.16     36.92          Rockwell Collins Inc.  ...     70.0    66.0
# 3     0.17     20.30   General Dynamics Corporation  ...     54.0    51.0
# 4     0.18     24.14   Honeywell International Inc.  ...     50.0    54.0
#
#   G_SCORE  ESG_PTILE  E_PTILE  S_PTILE  G_PTILE  E_WT  S_WT  G_WT
# 0    59.0      25.64    56.41    12.82    10.26  0.35  0.35   0.3
# 1    59.0       2.56     0.00     7.69    10.26  0.35  0.35   0.3
# 2    75.0      76.92    82.05    79.49    82.05  0.35  0.35   0.3
# 3    60.0      25.64    30.77    25.64    15.38  0.35  0.35   0.3
# 4    74.0      38.46    20.51    35.90    79.49  0.35  0.35   0.3
#
# [5 rows x 24 columns]

# %%
df_esg_sum1.dropna()
# Out:
#          DATE       SPX15       SPX17  SPX1517        P15        P17  \
# 0    20151231    2,063.4     2,673.6       0.3    146.41     294.91
# 2    20151231    2,063.4     2,673.6       0.3     93.27     135.62
# 3    20151231    2,063.4     2,673.6       0.3    139.26     203.45
# 4    20151231    2,063.4     2,673.6       0.3    103.87     153.36
# 5    20151231    2,063.4     2,673.6       0.3     30.90      68.25
# 6    20151231    2,063.4     2,673.6       0.3    120.94     197.85
# 7    20151231    2,063.4     2,673.6       0.3    219.80     321.05
# 8    20151231    2,063.4     2,673.6       0.3    190.08     306.91
# 11   20151231    2,063.4     2,673.6       0.3    125.74     187.85
# 12   20151231    2,063.4     2,673.6       0.3     48.97      87.25
# 14   20151231    2,063.4     2,673.6       0.3     39.96      27.20
# 15   20151231    2,063.4     2,673.6       0.3     42.45      56.59
# 16   20151231    2,063.4     2,673.6       0.3     96.90     127.57
# 17   20151231    2,063.4     2,673.6       0.3     43.92      51.09
# 19   20151231    2,063.4     2,673.6       0.3     16.29      20.95
# 20   20151231    2,063.4     2,673.6       0.3     33.31      32.31
# 22   20151231    2,063.4     2,673.6       0.3    124.45     176.66
# 23   20151231    2,063.4     2,673.6       0.3     46.59      58.54
# 24   20151231    2,063.4     2,673.6       0.3    116.20     125.14
# 25   20151231    2,063.4     2,673.6       0.3     14.17      12.49
# 26   20151231    2,063.4     2,673.6       0.3     34.33      40.99
# 27   20151231    2,063.4     2,673.6       0.3     45.56      50.88
# 28   20151231    2,063.4     2,673.6       0.3     57.32     150.72
# 29   20151231    2,063.4     2,673.6       0.3    238.09     311.35
# 30   20151231    2,063.4     2,673.6       0.3     19.00      25.40
# 31   20151231    2,063.4     2,673.6       0.3     17.05      29.52
# 32   20151231    2,063.4     2,673.6       0.3     38.17      49.72
# 33   20151231    2,063.4     2,673.6       0.3     63.68      85.70
# 34   20151231    2,063.4     2,673.6       0.3     60.40      92.32
# 35   20151231    2,063.4     2,673.6       0.3     28.53      35.49
# ..        ...         ...         ...      ...        ...        ...
# 951  20151231    2,063.4     2,673.6       0.3     60.30      63.24
# 952  20151231    2,063.4     2,673.6       0.3     51.85      63.18
# 953  20151231    2,063.4     2,673.6       0.3     69.25      81.39
# 954  20151231    2,063.4     2,673.6       0.3     27.69      39.41
# 955  20151231    2,063.4     2,673.6       0.3     32.29      30.62
# 957  20151231    2,063.4     2,673.6       0.3     27.78      32.24
# 958  20151231    2,063.4     2,673.6       0.3     29.16      36.15
# 960  20151231    2,063.4     2,673.6       0.3     31.73      42.61
# 961  20151231    2,063.4     2,673.6       0.3     18.54      26.88
# 962  20151231    2,063.4     2,673.6       0.3    104.91     156.19
# 963  20151231    2,063.4     2,673.6       0.3     42.26      54.91
# 964  20151231    2,063.4     2,673.6       0.3     19.82      25.67
# 965  20151231    2,063.4     2,673.6       0.3     11.09      28.48
# 966  20151231    2,063.4     2,673.6       0.3     26.66      32.91
# 967  20151231    2,063.4     2,673.6       0.3     51.34      73.26
# 968  20151231    2,063.4     2,673.6       0.3     36.56      63.96
# 969  20151231    2,063.4     2,673.6       0.3     53.92      44.83
# 970  20151231    2,063.4     2,673.6       0.3     38.99      51.50
# 971  20151231    2,063.4     2,673.6       0.3     65.23      85.18
# 973  20151231    2,063.4     2,673.6       0.3     37.22      45.58
# 974  20151231    2,063.4     2,673.6       0.3     34.34      30.95
# 975  20151231    2,063.4     2,673.6       0.3     61.30      39.78
# 976  20151231    2,063.4     2,673.6       0.3     47.27      48.09
# 977  20151231    2,063.4     2,673.6       0.3     94.85     106.92
# 981  20151231    2,063.4     2,673.6       0.3     34.26      46.95
# 982  20151231    2,063.4     2,673.6       0.3     43.46      65.02
# 983  20151231    2,063.4     2,673.6       0.3     52.23      66.43
# 984  20151231    2,063.4     2,673.6       0.3     43.16      52.80
# 985  20151231    2,063.4     2,673.6       0.3     30.27      39.23
# 986  20151231    2,063.4     2,673.6       0.3     36.40      48.11
#
#       RTN1517   REL_RTN        ROE  \
# 0       1.01      0.72      46.22
# 2       0.45      0.16      36.92
# 3       0.46      0.17      20.30
# 4       0.48      0.18      24.14
# 5       1.21      0.91       3.25
# 6       0.64      0.34      11.18
# 7       0.46      0.16      86.90
# 8       0.61      0.32      23.18
# 11      0.49      0.20      21.20
# 12      0.78      0.49      23.03
# 14     (0.32)    (0.62)     10.80
# 15      0.33      0.04      13.98
# 16      0.32      0.02      19.23
# 17      0.16     (0.13)     18.28
# 19      0.29     (0.01)     19.91
# 20     (0.03)    (0.33)     94.02
# 22      0.42      0.12      22.40
# 23      0.26     (0.04)     48.60
# 24      0.08     (0.22)      2.30
# 25     (0.12)    (0.41)      4.84
# 26      0.19     (0.10)     10.12
# 27      0.12     (0.18)     28.54
# 28      1.63      1.33      19.78
# 29      0.31      0.01     (37.25)
# 30      0.34      0.04       6.63
# 31      0.73      0.44       2.03
# 32      0.30      0.01       9.13
# 33      0.35      0.05      15.78
# 34      0.53      0.23       9.15
# 35      0.24     (0.05)     (4.28)
# ..        ...       ...        ...
# 951     0.05     (0.25)     13.65
# 952     0.22     (0.08)      8.37
# 953     0.18     (0.12)      9.58
# 954     0.42      0.13       7.16
# 955    (0.05)    (0.35)      1.70
# 957     0.16     (0.14)      6.80
# 958     0.24     (0.06)      9.49
# 960     0.34      0.05      11.12
# 961     0.45      0.15       9.91
# 962     0.49      0.19      12.99
# 963     0.30      0.00     (17.11)
# 964     0.30     (0.00)      8.80
# 965     1.57      1.27       1.35
# 966     0.23     (0.06)     12.60
# 967     0.43      0.13       7.24
# 968     0.75      0.45       7.19
# 969    (0.17)    (0.46)      9.56
# 970     0.32      0.03      12.76
# 971     0.31      0.01       9.29
# 973     0.22     (0.07)      9.38
# 974    (0.10)    (0.39)     10.95
# 975    (0.35)    (0.65)     11.15
# 976     0.02     (0.28)      9.85
# 977     0.13     (0.17)     10.39
# 981     0.37      0.07      10.50
# 982     0.50      0.20      10.56
# 983     0.27     (0.02)     13.50
# 984     0.22     (0.07)      9.83
# 985     0.30      0.00      13.41
# 986     0.32      0.03      10.33
#
#                                              NAME  ...  E_SCORE S_SCORE  \
# 0                              The Boeing Company  ...     62.0    45.0
# 2                           Rockwell Collins Inc.  ...     70.0    66.0
# 3                    General Dynamics Corporation  ...     54.0    51.0
# 4                    Honeywell International Inc.  ...     50.0    54.0
# 5                                        KLX Inc.  ...     41.0    43.0
# 6                L-3 Communications Holdings Inc.  ...     46.0    50.0
# 7                     Lockheed Martin Corporation  ...     73.0    64.0
# 8                    Northrop Grumman Corporation  ...     59.0    66.0
# 11                               Raytheon Company  ...     68.0    62.0
# 12               Spirit AeroSystems Holdings Inc.  ...     53.0    59.0
# 14                             Triumph Group Inc.  ...     43.0    48.0
# 15                                   Textron Inc.  ...     54.0    56.0
# 16                      United Technologies Corp.  ...     61.0    56.0
# 17                                BorgWarner Inc.  ...     68.0    61.0
# 19                             Gentex Corporation  ...     52.0    57.0
# 20             The Goodyear Tire & Rubber Company  ...     71.0    76.0
# 22                               Lear Corporation  ...     54.0    53.0
# 23                                   Tenneco Inc.  ...     56.0    59.0
# 24                            Visteon Corporation  ...     68.0    65.0
# 25                                 Ford Motor Co.  ...     67.0    75.0
# 26                         General Motors Company  ...     56.0    65.0
# 27                           Harley-Davidson Inc.  ...     44.0    58.0
# 28                           Thor Industries Inc.  ...     43.0    52.0
# 29                                     Tesla Inc.  ...     62.0    50.0
# 30                           Associated Banc-Corp  ...     34.0    56.0
# 31                    Bank of America Corporation  ...     79.0    68.0
# 32                               BB&T Corporation  ...     33.0    59.0
# 33                     Bank of Hawaii Corporation  ...     32.0    61.0
# 34                      BOK Financial Corporation  ...     39.0    62.0
# 35                                   Popular Inc.  ...     32.0    66.0
# ..                                            ...  ...      ...     ...
# 951                          Edison International  ...     49.0    62.0
# 952                             Eversource Energy  ...     67.0    75.0
# 953                           Entergy Corporation  ...     56.0    73.0
# 954                            Exelon Corporation  ...     74.0    76.0
# 955                             FirstEnergy Corp.  ...     38.0    59.0
# 957              Great Plains Energy Incorporated  ...     40.0    63.0
# 958             Hawaiian Electric Industries Inc.  ...     38.0    58.0
# 960                    Alliant Energy Corporation  ...     49.0    68.0
# 961                      MDU Resources Group Inc.  ...     49.0    64.0
# 962                           NextEra Energy Inc.  ...     49.0    75.0
# 963                     National Fuel Gas Company  ...     41.0    57.0
# 964                                 NiSource Inc.  ...     57.0    69.0
# 965                               NRG Energy Inc.  ...     47.0    65.0
# 966                              OGE Energy Corp.  ...     44.0    65.0
# 967                                  ONE Gas Inc.  ...     42.0    59.0
# 968                       Ormat Technologies Inc.  ...     66.0    57.0
# 969                              PG&E Corporation  ...     72.0    68.0
# 970  Public Service Enterprise Group Incorporated  ...     49.0    76.0
# 971             Pinnacle West Capital Corporation  ...     65.0    80.0
# 973             Portland General Electric Company  ...     44.0    60.0
# 974                               PPL Corporation  ...     46.0    63.0
# 975                             SCANA Corporation  ...     51.0    58.0
# 976                          The Southern Company  ...     54.0    68.0
# 977                                 Sempra Energy  ...     57.0    89.0
# 981                               UGI Corporation  ...     32.0    56.0
# 982                           Vectren Corporation  ...     46.0    64.0
# 983                         WEC Energy Group Inc.  ...     54.0    73.0
# 984                            Westar Energy Inc.  ...     48.0    61.0
# 985                             Aqua America Inc.  ...     46.0    58.0
# 986                              Xcel Energy Inc.  ...     62.0    78.0
#
#     G_SCORE  ESG_PTILE  E_PTILE  S_PTILE  G_PTILE  E_WT  S_WT  G_WT
# 0      59.0      25.64    56.41    12.82    10.26  0.35  0.35  0.30
# 2      75.0      76.92    82.05    79.49    82.05  0.35  0.35  0.30
# 3      60.0      25.64    30.77    25.64    15.38  0.35  0.35  0.30
# 4      74.0      38.46    20.51    35.90    79.49  0.35  0.35  0.30
# 5      66.0       5.13     7.69     0.00    53.85  0.35  0.35  0.30
# 6      57.0      12.82    15.38    23.08     5.13  0.35  0.35  0.30
# 7      78.0      79.49    87.18    74.36    84.62  0.35  0.35  0.30
# 8      81.0      74.36    46.15    79.49    92.31  0.35  0.35  0.30
# 11     60.0      53.85    69.23    61.54    15.38  0.35  0.35  0.30
# 12     69.0      43.59    28.21    56.41    66.67  0.35  0.35  0.30
# 14     64.0      12.82    10.26    15.38    41.03  0.35  0.35  0.30
# 15     65.0      35.90    30.77    46.15    46.15  0.35  0.35  0.30
# 16     62.0      43.59    51.28    46.15    33.33  0.35  0.35  0.30
# 17     67.0      63.24    54.41    51.47    75.00  0.35  0.40  0.25
# 19     64.0      26.47    19.12    41.18    60.29  0.35  0.40  0.25
# 20     64.0      83.82    64.71    85.29    60.29  0.35  0.40  0.25
# 22     68.0      26.47    23.53    22.06    80.88  0.35  0.40  0.25
# 23     68.0      33.82    26.47    47.06    80.88  0.35  0.40  0.25
# 24     79.0      82.35    54.41    66.18    97.06  0.35  0.40  0.25
# 25     71.0      87.23    70.21    80.85    78.72  0.45  0.30  0.25
# 26     67.0      61.70    53.19    76.60    65.96  0.45  0.30  0.25
# 27     75.0      46.81    25.53    61.70    89.36  0.45  0.30  0.25
# 28     73.0      34.04    21.28    40.43    85.11  0.45  0.30  0.25
# 29     55.0      46.81    63.83    34.04    21.28  0.45  0.30  0.25
# 30     53.0      23.52    16.86    11.40    60.10  0.30  0.35  0.35
# 31     60.0      86.70    95.72    70.78    80.05  0.30  0.35  0.35
# 32     48.0      17.34    10.45    24.94    36.34  0.30  0.35  0.35
# 33     54.0      36.10     2.14    37.53    62.71  0.30  0.35  0.35
# 34     50.0      42.76    37.77    47.51    45.37  0.30  0.35  0.35
# 35     51.0      36.10     2.14    64.85    50.36  0.30  0.35  0.35
# ..      ...        ...      ...      ...      ...   ...   ...   ...
# 951    72.0      44.23    35.38    45.38    56.15  0.45  0.30  0.25
# 952    73.0      81.15    82.69    81.15    59.62  0.45  0.30  0.25
# 953    77.0      71.15    62.69    76.15    75.00  0.45  0.30  0.25
# 954    75.0      89.23    92.31    83.46    64.23  0.45  0.30  0.25
# 955    73.0      23.46     4.23    33.85    59.62  0.45  0.30  0.25
# 957    66.0      23.46    10.77    50.38    39.23  0.45  0.30  0.25
# 958    80.0      27.31     4.23    31.54    83.08  0.45  0.30  0.25
# 960    76.0      54.23    35.38    65.77    71.54  0.45  0.30  0.25
# 961    75.0      49.62    35.38    51.92    64.23  0.45  0.30  0.25
# 962    69.0      58.46    35.38    81.15    47.31  0.45  0.30  0.25
# 963    64.0      18.46    14.23    27.31    31.54  0.45  0.30  0.25
# 964    86.0      76.54    65.00    68.46    94.23  0.45  0.30  0.25
# 965    78.0      49.62    29.23    54.62    76.92  0.45  0.30  0.25
# 966    74.0      40.38    21.92    54.62    62.31  0.45  0.30  0.25
# 967    82.0      37.69    16.54    33.85    87.69  0.45  0.30  0.25
# 968    73.0      69.23    81.54    27.31    59.62  0.45  0.30  0.25
# 969    72.0      81.15    90.77    65.77    56.15  0.45  0.30  0.25
# 970    75.0      66.15    35.38    83.46    64.23  0.45  0.30  0.25
# 971    76.0      83.85    80.00    92.31    71.54  0.45  0.30  0.25
# 973    75.0      34.23    21.92    35.38    64.23  0.45  0.30  0.25
# 974    69.0      37.69    25.77    50.38    47.31  0.45  0.30  0.25
# 975    69.0      40.38    48.85    31.54    47.31  0.45  0.30  0.25
# 976    73.0      62.69    58.85    65.77    59.62  0.45  0.30  0.25
# 977    84.0      88.46    65.00    98.85    91.54  0.45  0.30  0.25
# 981    68.0      10.77     0.38    24.23    45.38  0.45  0.30  0.25
# 982    70.0      37.69    25.77    51.92    50.38  0.45  0.30  0.25
# 983    78.0      71.15    58.85    76.15    76.92  0.45  0.30  0.25
# 984    75.0      44.23    33.08    40.38    64.23  0.45  0.30  0.25
# 985    76.0      37.69    25.77    31.54    71.54  0.45  0.30  0.25
# 986    78.0      81.15    75.38    88.08    76.92  0.45  0.30  0.25
#
# [865 rows x 24 columns]

# %%
df_esg_clean = df_esg_sum1.dropna()

# %%
df_esg_clean["REL_RTN"] = df_esg_clean["REL_RTN"].convert_objects(convert_numeric=True)
df_esg_clean["ROE"] = df_esg_clean["ROE"].convert_objects(convert_numeric=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_esg_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 865 entries, 0 to 986
# Data columns (total 24 columns):
# DATE               865 non-null int64
# SPX15              865 non-null object
# SPX17              865 non-null object
# SPX1517            865 non-null float64
# P15                865 non-null object
# P17                865 non-null object
# RTN1517            865 non-null object
# REL_RTN            453 non-null float64
# ROE                761 non-null float64
# NAME               865 non-null object
# TICKER             865 non-null object
# PEER_GROUP         865 non-null object
# COUNTRY            865 non-null object
# TOTAL_ESG_SCORE    865 non-null float64
# E_SCORE            865 non-null float64
# S_SCORE            865 non-null float64
# G_SCORE            865 non-null float64
# ESG_PTILE          865 non-null float64
# E_PTILE            865 non-null float64
# S_PTILE            865 non-null float64
# G_PTILE            865 non-null float64
# E_WT               865 non-null float64
# S_WT               865 non-null float64
# G_WT               865 non-null float64
# dtypes: float64(14), int64(1), object(9)
# memory usage: 168.9+ KB

# %%
df_esg_clean.head()
# Out:
#        DATE       SPX15       SPX17  SPX1517        P15        P17  RTN1517  \
# 0  20151231    2,063.4     2,673.6       0.3    146.41     294.91     1.01
# 2  20151231    2,063.4     2,673.6       0.3     93.27     135.62     0.45
# 3  20151231    2,063.4     2,673.6       0.3    139.26     203.45     0.46
# 4  20151231    2,063.4     2,673.6       0.3    103.87     153.36     0.48
# 5  20151231    2,063.4     2,673.6       0.3     30.90      68.25     1.21
#
#    REL_RTN    ROE                          NAME  ...  E_SCORE S_SCORE G_SCORE  \
# 0     0.72  46.22            The Boeing Company  ...     62.0    45.0    59.0
# 2     0.16  36.92         Rockwell Collins Inc.  ...     70.0    66.0    75.0
# 3     0.17  20.30  General Dynamics Corporation  ...     54.0    51.0    60.0
# 4     0.18  24.14  Honeywell International Inc.  ...     50.0    54.0    74.0
# 5     0.91   3.25                      KLX Inc.  ...     41.0    43.0    66.0
#
#    ESG_PTILE  E_PTILE  S_PTILE  G_PTILE  E_WT  S_WT  G_WT
# 0      25.64    56.41    12.82    10.26  0.35  0.35   0.3
# 2      76.92    82.05    79.49    82.05  0.35  0.35   0.3
# 3      25.64    30.77    25.64    15.38  0.35  0.35   0.3
# 4      38.46    20.51    35.90    79.49  0.35  0.35   0.3
# 5       5.13     7.69     0.00    53.85  0.35  0.35   0.3
#
# [5 rows x 24 columns]

# %% [markdown]
# We'll be using a linear regression model, so we must examine our features' distributions to ensure that the normal distribution assumption is satisfied.  We'll also check for outliers during this step.  Finally, we'll examine whether correlations and collinearity exist among/betwen our features.

# %%
plt.figure()
plt.subplot()
plt.hist(df_esg_clean.REL_RTN)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-2e6e25231c89> in <module>()
#       1 plt.figure()
#       2 plt.subplot()
# ----> 3 plt.hist(df_esg_clean.REL_RTN)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6163             # this will automatically overwrite bins,
#    6164             # so that each histogram uses the same bins
# -> 6165             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6166             m = m.astype(float)  # causes problems later if it's an int
#    6167             if mlast is None:
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     665     if first_edge > last_edge:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([first_edge, last_edge])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
plt.boxplot(df_esg_clean.REL_RTN)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:4291: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1856: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1863: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1871: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)
# {'boxes': [<matplotlib.lines.Line2D at 0x1a1ddea550>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a1ddeaf60>,
#   <matplotlib.lines.Line2D at 0x1a1ddf33c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1ddf3c18>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1ddf37f0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a1ddea6a0>,
#   <matplotlib.lines.Line2D at 0x1a1ddeab38>]}

# %%
plt.figure()
plt.subplot()
plt.boxplot(df_esg_clean.TOTAL_ESG_SCORE)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a1dc56da0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a1dc5d7f0>,
#   <matplotlib.lines.Line2D at 0x1a1dc5dc18>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1dc664a8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1dc66080>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a1dc56ef0>,
#   <matplotlib.lines.Line2D at 0x1a1dc5d3c8>]}

# %%
plt.figure()
plt.subplot()
plt.hist(df_esg_clean.TOTAL_ESG_SCORE)
# Out:
# (array([ 74., 206., 171., 159., 116.,  84.,  43.,   8.,   3.,   1.]),
#  array([42. , 46.9, 51.8, 56.7, 61.6, 66.5, 71.4, 76.3, 81.2, 86.1, 91. ]),
#  <a list of 10 Patch objects>)

# %%
esg_plot = plt.figure()
esg_hist = esg_plot.add_subplot(2, 1, 1)
esg_box = esg_plot.add_subplot(2, 1, 2)
esg_hist.hist('TOTAL_ESG_SCORE')
esg_box.boxplot('TOTAL_ESG_SCORE')
esg_plot = plt.subplots(2, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-28a7781c3fa1> in <module>()
#       3 esg_box = esg_plot.add_subplot(2, 1, 2)
#       4 esg_hist.hist('TOTAL_ESG_SCORE')
# ----> 5 esg_box.boxplot('TOTAL_ESG_SCORE')
#       6 esg_plot = plt.subplots(2, 2)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder)
#    3266
#    3267         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3268                                        labels=labels, autorange=autorange)
#    3269         if notch is None:
#    3270             notch = rcParams['boxplot.notch']
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1822
#    1823         # arithmetic mean
# -> 1824         stats['mean'] = np.mean(x)
#    1825
#    1826         # medians and quartiles
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
plt.figure()
plt.subplot()
plt.boxplot(df_esg_clean.E_SCORE)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a1d89fac8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a1d8a6518>,
#   <matplotlib.lines.Line2D at 0x1a1d8a6940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1d8ae1d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1d8a6d68>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a1d89fc18>,
#   <matplotlib.lines.Line2D at 0x1a1d8a60f0>]}

# %%
plt.figure()
plt.subplot()
plt.boxplot(df_esg_clean.S_SCORE)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a1d966780>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a1d96c1d0>,
#   <matplotlib.lines.Line2D at 0x1a1d96c5f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1d96ce48>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1d96ca20>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a1d9668d0>,
#   <matplotlib.lines.Line2D at 0x1a1d966d68>]}

# %%
plt.figure()
plt.subplot()
plt.boxplot(df_esg_clean.G_SCORE)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a1da1fa58>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a1da284a8>,
#   <matplotlib.lines.Line2D at 0x1a1da288d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a1da31160>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a1da28cf8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a1da1fba8>,
#   <matplotlib.lines.Line2D at 0x1a1da28080>]}

# %%
plt.scatter(df_esg_clean.TOTAL_ESG_SCORE, df_esg_clean.REL_RTN)

# %%
plt.scatter(df_esg_clean.E_SCORE, df_esg_clean.REL_RTN)

# %%
plt.scatter(df_esg_clean.S_SCORE, df_esg_clean.REL_RTN)

# %%
plt.scatter(df_esg_clean.G_SCORE, df_esg_clean.REL_RTN)

# %%
esg_corr_mtrx = df_esg_clean.corr()

# %%
plt.figure()
sns.heatmap(esg_corr_mtrx)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df_esg_clean)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2961: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=20151231.0, right=20151231.0
#   'left=%s, right=%s') % (left, right))
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2961: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.3, right=0.3
#   'left=%s, right=%s') % (left, right))
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3285: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=20151231.0, top=20151231.0
#   'bottom=%s, top=%s') % (bottom, top))
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3285: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.3, top=0.3
#   'bottom=%s, top=%s') % (bottom, top))
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea59160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21cd68d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f445e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed918d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d7e2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d7e320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f6beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f9af98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fbac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ff0ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2202a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22066668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2209ea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a220c4f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a220fcf28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a221434a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2217a518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a221b5438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a221dd978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22217978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22250898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22288978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a221f61d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a222f72e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2232f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22369438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223a14a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223c9eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22402eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2243af28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22480048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2240dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a224e0898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2251a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22553978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2258b9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225c0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225f9198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22632208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2266b208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225cf550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226d06d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22708748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227456d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2277d6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a227b2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227eb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22824588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2285f518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22893128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228ca198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229060b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22931f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22954978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229a4ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229d8e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a132e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a4fc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a84668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22abc668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22af7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b31ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ad49e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b9e668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22bbd898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c14588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c4c4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c75d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22cadd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ce4cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d2b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d59668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d925f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22dc95f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e01b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22e0c9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e72128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22eae128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ee45f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f1f588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f49ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f7fa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22fbaa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ff8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f9ad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230636d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2309d6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230d6668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23112b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223b00f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23153748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2318d748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231c5668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23197630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2327d198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232b7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232f0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2332a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23352c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2338cb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233c6b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2340a048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23436588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2346e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234a84a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a234e1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234ecf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23550048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2358a048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235c2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235fb518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236269e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23662978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23699978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236d5898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2366c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237404a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2377a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237b3908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237ef908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23815f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23852eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23887eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238ce3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238f49e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23935978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2396e978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a239a3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a239b2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a174a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a4e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a889e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ac0908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ae6e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b22dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23b5f278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b99d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b376d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c06908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c3ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c78d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23cb1cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ce73c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d21898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d5a898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d95898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23dc82e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e003c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e3e3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e773c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23e528d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ed8eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f12eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f49e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f8f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23fbc898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ff4828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2402e748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24066748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23fcb0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a240caf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24104f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24141eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24177eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a241ac9e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a241e6e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24220e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24255e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2428f908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242c6978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24301898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2433c898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243210b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243a8518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243e4518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2441c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24456a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24481f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244baeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244f1eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a245373c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2455e898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2459c7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245d57b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2460bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24618e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246ce358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24706358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24740828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247797b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247a5cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247dbc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24815cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24850c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247efa58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a248bf7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248f8c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24931c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2496cba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249a1278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249da748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a13748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a4e6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a83278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ab72e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24af62e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b2d278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24aff860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b8fe48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bcae48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24c00e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c472e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c70908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24cac908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ce4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d1cdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d30630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d66f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d85978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24dd9f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e10f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e446d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e80b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ebab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ef3a58>]],
#       dtype=object)
